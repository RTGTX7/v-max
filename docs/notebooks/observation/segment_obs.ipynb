# %%
import os


os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"


from functools import partial

import jax
import mediapy
from utils import expert_step, run_and_log_scenario
from waymax import dynamics

from vmax import PATH_TO_PROJECT
from vmax.simulator import datasets, make_data_generator, make_env, visualization

# %%
MAX_NUM_OBJECTS = 64
INCLUDE_SDC_PATHS = True
SEED = 0
path_dataset = "/media/rtgtx7/加速盘/data/validation.tfrecord"  # TO FILL


data_generator = make_data_generator(
    path=path_dataset,
    max_num_objects=MAX_NUM_OBJECTS,
    include_sdc_paths=INCLUDE_SDC_PATHS,
    seed=SEED,
)


env = make_env(
    max_num_objects=MAX_NUM_OBJECTS,
    dynamics_model=dynamics.InvertibleBicycleModel(normalize_actions=True),
    observation_type="segment",
    observation_config={
        "obs_past_num_steps": 5,
        "objects": {
            "features": ["waypoints", "velocity", "yaw", "size", "valid"],
            "num_closest_objects": 8,
        },
        "roadgraphs": {
            "features": ["waypoints", "direction", "types", "valid"],
            "meters_box": {"front": 50, "back": 10, "left": 12, "right": 12},
            "max_meters": 50,
            "max_num_lanes": 10,
            "max_num_points_per_lane": 20,
        },
        "traffic_lights": {
            "features": ["waypoints", "state", "valid"],
        },
        "path_target": {
            "features": ["waypoints"],
            "num_points": 10,
            "points_gap": 5,
        },
    },
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 15
#       4 path_dataset = "/media/rtgtx7/加速盘/data/validation.tfrecord"  # TO FILL
#       7 data_generator = make_data_generator(
#       8     path=path_dataset,
#       9     max_num_objects=MAX_NUM_OBJECTS,
#      10     include_sdc_paths=INCLUDE_SDC_PATHS,
#      11     seed=SEED,
#      12 )
# ---> 15 env = make_env(
#      16     max_num_objects=MAX_NUM_OBJECTS,
#      17     dynamics_model=dynamics.InvertibleBicycleModel(normalize_actions=True),
#      18     observation_type="segment",
#      19     observation_config={
#      20         "obs_past_num_steps": 5,
#      21         "objects": {
#      22             "features": ["waypoints", "velocity", "yaw", "size", "valid"],
#      23             "num_closest_objects": 8,
#      24         },
#      25         "roadgraphs": {
#      26             "features": ["waypoints", "direction", "types", "valid"],
#      27             "meters_box": {"front": 50, "back": 10, "left": 12, "right": 12},
#      28             "max_meters": 50,
#      29             "max_num_lanes": 10,
#      30             "max_num_points_per_lane": 20,
#      31         },
#      32         "traffic_lights": {
#      33             "features": ["waypoints", "state", "valid"],
#      34         },
#      35         "path_target": {
#      36             "features": ["waypoints"],
#      37             "num_points": 10,
#      38             "points_gap": 5,
#      39         },
#      40     },
#      41 )
#
# File ~/Desktop/AD/v-max/vmax/simulator/sim_factory.py:91, in make_env(max_num_objects, dynamics_model, observation_type, observation_config, reward_type, reward_config, noisy_init)
#      89 # Register metrics
#      90 for key in metrics._VMAX_METRICS_REGISTRY:
# ---> 91     waymax_metrics.register_metric(key, metrics.get_metrics(key))
#      93 env_config = _config.EnvironmentConfig(
#      94     max_num_objects=max_num_objects,
#      95     metrics=_config.MetricsConfig(metrics_to_run=metrics_to_run),
#      96     init_steps=init_steps,
#      97 )
#      98 waymax_env = env.PlanningAgentEnvironment(dynamics_model, env_config)
#
# File ~/Desktop/AD/v-max/venv/lib/python3.13/site-packages/waymax/metrics/metric_factory.py:78, in register_metric(metric_name, metric)
#      68 """Register a metric.
#      69
#      70 This function registers a metric so that it can be included in a MetricsConfig
#    (...)     75   metric: The metric to register.
#      76 """
#      77 if metric_name in _METRICS_REGISTRY:
# ---> 78   raise ValueError(f'Metric {metric_name} has already been registered.')
#      79 _METRICS_REGISTRY[metric_name] = metric
#
# ValueError: Metric run_red_light has already been registered.

# %%
scenario = next(data_generator)

simulator_state = env.reset(scenario)

# %%
img = visualization.plot_input_agent(simulator_state, env)
mediapy.show_image(img)

# %%
_step = partial(expert_step, env)
_jitted_expert_step = jax.jit(_step)

# %%
for _i in range(0):
    scenario = next(data_generator)
    imgs = run_and_log_scenario(env, scenario, _jitted_expert_step)
    mediapy.show_video(imgs, fps=10)
